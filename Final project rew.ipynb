# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
# <b>Привет Сергей!</b>
#
# Меня зовут  Евгений Арзамасцев, я твой тимлид по этому проекту. Буду проверять следующие этапы твоей работы:
# <p> * План работ и уточняющие вопросы
# <p> * Основной код разработки модели
# <p> * Отчет о проделанной работе
#
#  Предлагаю общаться на «ты» :) Но если это не удобно - дай знать, и мы перейдем на "вы".
#
# Моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать отличным специалистом по Data Science. Ты уже проделал большую работу над проектами этого курса. Сейчас у тебя Финальный Спринт - дипломная работа. Моя цель - помочь тебе сделать ее максимально качественно, чтобы было не стыдно ссылаться на данную работу в своем резюме!
#
# Ниже ты найдешь мои комментарии - **пожалуйста, не перемещай, не изменяй и не удаляй их**. Увидев у тебя ошибку, в первый раз я лишь укажу на ее наличие и дам тебе возможность самому найти и исправить ее. На реальной работе твой начальник будет поступать так же, а я пытаюсь подготовить тебя именно к таким ситуациям. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку. Я буду использовать цветовую разметку:
#
# <div class="alert alert-danger">
# <b>Комментарий тимлида ❌:</b> Так выделены самые важные замечания. Без их отработки проект не будет принят. </div>
#
# <div class="alert alert-warning">
# <b>Комментарий тимлида ⚠️:</b> Так выделены небольшие замечания. Я надеюсь, что их ты тоже учтешь - твой проект от этого станет только лучше. Но настаивать на их отработке не буду.
#
# </div>
#
# <div class="alert alert-success">
# <b>Комментарий тимлида ✔️:</b> Так я выделяю все остальные комментарии.</div>
#
# Давай работать над проектом в диалоге: **если ты что-то меняешь в проекте или отвечаешь на мои комменатри — пиши об этом.** Мне будет легче отследить изменения, если ты выделишь свои комментарии:
# <div class="alert alert-info"> <b>Комментарий студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее.

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Привет, Евгений. Конечно на ты. Спасибо за твое ревью, попытаюсь все исправить. </div>

# %% [markdown]
# # Отток клиентов

# %% [markdown]
# Итак, нам поставлена задача обучить модель, прогнозирующую отток клиентов оператора связи «Ниединогоразрыва.ком», с целью сохранения лояльности таких клиентов путем предоставления им специальных промокодов и условий. Для решения задачи компания предоставила данные по клиентам по состоянию на 1 февраля 2020 года. Необходимым условием при обучении модели является получение метрики AUC-ROC не менее 0,75.

# %% [markdown]
# Поставленная задача понятна. Для решения разделим ее на три этапа:
#
# 1. Загрузка и первичный анализ данных. Построение плана исследования.
# 2. Обучение не менее 3 различных моделей и поиск наилучших гиперпараметров.
# 3. В случае получения необходимой метрики, составление отчета о проделанной работе для передачи его в компанию.

# %% [markdown]
# <div class="alert alert-warning">
# <b>**Комментарий тимлида ✔️:**</b>
#
# 1. В описательной части есть немного информации о проекте и исходным данным. Но этого катастрофически мало для полноценной вводной части нормального исследования.
#
# 2. Есть план работ. Указанны некоторые этапы исследования. Хочется все-таки видеть более структурированный план, включающий в себя основные этапы (загрузка и предобработка, исследование, моделирование, подготовка отчета), и их декомпозицию на основные шаги в рамках каждого из этапов.
#
# 3. Данное исследование можно будет приложить к портфолио и показывать потенциальным работодателям на собесах. По этому предлагаю сразу же оформлять его в соответствии с требованиями к исследованию. В описательной части не хватает:
#
# - хорошего названия проекта
# - описание исходных данны
# - четко сформулированной цели проекта
#
# Касаемо цели - я рекомендую ее немного изменить и привести в соответствие с требованиями SMART. Если интересно - почитай вот тут https://www.carrotquest.io/blog/smart-goal/. Можно привести SMARTированную цель проекта уже потом, на следующем этапе.
#
# Рекомендую доработать этот раздел.
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Название добавил. По поводу плана, посчитал что логичнее было бы составить план после первичного анализа данных,так как в задании очень мало информации.</div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Прокрутил цель вголовераз сто, но не знаю как правильно ее оформить. Опять же, анных мало, нет никакой конкретной задачи по срокам сокращения оттока клиентов и ресурсов на исполнение, а так же данных по желаемому сокращению в процентах. Как поступить?</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>**Комментарий тимлида_v2 ✔️:**</b>
#
# Мы должны описать цель проекта, в нашем случае проект - это разработка модели. Соотвесттвенно, если говорить про конкретику, то в цель может выглядить примерно вот так: "На основании имеющихся данных в течение 2 недель разработать модель предсказания оттока клиентов телекомоператора с требуемым качеством по метрике ROC-AUC > 0.85".
# </div>

# %% [markdown]
# ## Этап загрузки и первичного анализа

# %% [markdown]
# ### Загрузка данных

# %% [markdown]
# Первым делом загрузим необходимые библиотеки

# %%
pip install phik
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import seaborn as sns

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import matplotlib.pyplot as plt

import phik
from phik.report import plot_correlation_matrix
from phik import report

from sklearn.model_selection import train_test_split

from sklearn.preprocessing import OrdinalEncoder 
from sklearn.model_selection import GridSearchCV
from catboost import CatBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import roc_auc_score
import numpy as np
from sklearn.utils import shuffle

# %% [markdown]
# Список загрузок будет пополняться по ходу исследования

# %% [markdown]
# #### Загрузим первый фаил.

# %%
try:
    contract = pd.read_csv('/datasets/final_provider/contract.csv')
except:
    contract = pd.read_csv('contract.csv')
contract
# Out:
#       customerID   BeginDate              EndDate            Type  \
# 0     7590-VHVEG  2020-01-01                   No  Month-to-month
# 1     5575-GNVDE  2017-04-01                   No        One year
# 2     3668-QPYBK  2019-10-01  2019-12-01 00:00:00  Month-to-month
# 3     7795-CFOCW  2016-05-01                   No        One year
# 4     9237-HQITU  2019-09-01  2019-11-01 00:00:00  Month-to-month
# ...          ...         ...                  ...             ...
# 7038  6840-RESVB  2018-02-01                   No        One year
# 7039  2234-XADUH  2014-02-01                   No        One year
# 7040  4801-JZAZL  2019-03-01                   No  Month-to-month
# 7041  8361-LTMKD  2019-07-01  2019-11-01 00:00:00  Month-to-month
# 7042  3186-AJIEK  2014-08-01                   No        Two year
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges
# 0                 Yes           Electronic check           29.85        29.85
# ...

# %% [markdown]
# <div class="alert alert-danger">
# <b>**Комментарий тимлида ❌:**</b>
#
# На платформе данные находятся в других папках. Соответственно я не могу проверить твой код. По умолчанию у тебя загружается файл из корневой директории. На Платформе это НЕ ТОТ файл, который нужен. По этому поменяй местами пути в конструкции try-except
#
# Пожалуйста доработай код, чтобы учесть альтернативные пути к данным - возможность загрузки данных через платформу (можно сделать так, чтобы и у тебя и на платформе все работало ок, например через конструкцию try-except). Файлы с данными находятся в папке '/datasets/final_provider/'
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Поменял местами пути загрузки в конструкции try-except. Хотяу себяпроверил, у меня загружается и из тетради и с платформы.</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>**Комментарий тимлида_v2 ✔️:**</b>
#
# В предыдущем варианте у тебя и должно было загружаться нормально, а вот с платформы - загружался не тот файл, хотя и похожий по содержанию.
# </div>
#
# И посмотрим состав данных

# %%
contract.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   BeginDate         7043 non-null   object
#  2   EndDate           7043 non-null   object
#  3   Type              7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7043 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 440.3+ KB

# %% [markdown]
# В первом же файле мы получили целевой признак в колонке 'EndDate'. Тип данных object, следовательно будем обрабатывать данные целевого признака. Так же, думаю, надо будет поменять тип данных для столбцов 'BeginDate' и 'TotalCharges'.

# %% [markdown]
# Другие колонци содержат категоральные данные, их так же для некоторых моделей будем кодировать.

# %% [markdown]
# Посмотрим на дисбаланс классов по целевому признаку

# %%
contract.query('EndDate == "No"').count()
# Out:
# customerID          5174
# BeginDate           5174
# EndDate             5174
# Type                5174
# PaperlessBilling    5174
# PaymentMethod       5174
# MonthlyCharges      5174
# TotalCharges        5174
# dtype: int64

# %% [markdown]
# Действительно дисбаланс имеется, а именно количество клиентов прекративших взаимоотношения с компанией составляет чуть менне трети от числа оставшихся лояльными. Держим дисбаланс на заметке, возможно, придется апсемплить базу.

# %% [markdown]
# Ну и на всякий случай посмотрим уникальные значения в столбцах с категоральными данными

# %%
contract['Type'].unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %%
contract['PaperlessBilling'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
contract['PaymentMethod'].unique()
# Out:
# array(['Electronic check', 'Mailed check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'], dtype=object)

# %% [markdown]
# Данные не содержат вбросов и аномалий, готовы к кодировке и обучению

# %% [markdown]
# <div class="alert alert-success">
# <b>**Комментарий тимлида ✔️:**</b>
#
# Ок, продолжаем исследование!
# </div>

# %% [markdown]
# #### Второй фаил

# %%
try:
    personal = pd.read_csv('/datasets/final_provider/personal.csv')
except:
    personal = pd.read_csv('personal.csv')
personal
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents
# 0     7590-VHVEG  Female              0     Yes         No
# 1     5575-GNVDE    Male              0      No         No
# 2     3668-QPYBK    Male              0      No         No
# 3     7795-CFOCW    Male              0      No         No
# 4     9237-HQITU  Female              0      No         No
# ...          ...     ...            ...     ...        ...
# 7038  6840-RESVB    Male              0     Yes        Yes
# 7039  2234-XADUH  Female              0     Yes        Yes
# 7040  4801-JZAZL  Female              0     Yes        Yes
# 7041  8361-LTMKD    Male              1     Yes         No
# 7042  3186-AJIEK    Male              0      No         No
#
# [7043 rows x 5 columns]

# %%
personal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   object
#  1   gender         7043 non-null   object
#  2   SeniorCitizen  7043 non-null   int64
#  3   Partner        7043 non-null   object
#  4   Dependents     7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %% [markdown]
# Здесь мы видим данные по каждому клиенту. Количество строк совпадает с первым файлом, что логично, а также обе базы имеют общую колонку 'customerID' что позволит нам объединить данные.
#
# Состав данных понятен. В основном категоральные. Будем кондировать.

# %% [markdown]
# На всякий случай убедимся, что нет аномалий.

# %%
personal['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
personal['SeniorCitizen'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
personal['Partner'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
personal['Dependents'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %% [markdown]
# Данные готовы к работе.

# %% [markdown]
# Посмотрим распределение клиентов по категориям. В этом нет пока никакой необходимости. Просто интересно

# %%
sns.countplot(personal.gender)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
sns.countplot(personal.Partner)
# Out:
# <AxesSubplot:xlabel='Partner', ylabel='count'>

# %%
sns.countplot(personal.Dependents)
# Out:
# <AxesSubplot:xlabel='Dependents', ylabel='count'>

# %%
sns.countplot(personal.SeniorCitizen)
# Out:
# <AxesSubplot:xlabel='SeniorCitizen', ylabel='count'>

# %% [markdown]
# Мужчин и женщин среди клиентов компании примерно поровну, как и клиентов состоящих и несостоящих в отношениях с партнером. В то же время, пенсионеров примерно в пять раз меньше, чем работающих. Так же, среди клиентгов компании большую часть составляют те у кого нет иждевенцев. Соотношение примерно три к одному.

# %% [markdown]
# <div class="alert alert-success">
# <b>**Комментарий тимлида ✔️:**</b>
#
# Ок, изучили еще один блок данных, продолжаем исследование! Круто, что есть визуализация!
# </div>

# %% [markdown]
# #### Третий фаил

# %%
try:
    internet = pd.read_csv('/datasets/final_provider/internet.csv')
except:
    internet = pd.read_csv('internet.csv')
internet
# Out:
#       customerID InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0     7590-VHVEG             DSL             No          Yes               No
# 1     5575-GNVDE             DSL            Yes           No              Yes
# 2     3668-QPYBK             DSL            Yes          Yes               No
# 3     7795-CFOCW             DSL            Yes           No              Yes
# 4     9237-HQITU     Fiber optic             No           No               No
# ...          ...             ...            ...          ...              ...
# 5512  6840-RESVB             DSL            Yes           No              Yes
# 5513  2234-XADUH     Fiber optic             No          Yes              Yes
# 5514  4801-JZAZL             DSL            Yes           No               No
# 5515  8361-LTMKD     Fiber optic             No           No               No
# 5516  3186-AJIEK     Fiber optic            Yes           No              Yes
#
# ...

# %%
internet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5517 entries, 0 to 5516
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        5517 non-null   object
#  1   InternetService   5517 non-null   object
#  2   OnlineSecurity    5517 non-null   object
#  3   OnlineBackup      5517 non-null   object
#  4   DeviceProtection  5517 non-null   object
#  5   TechSupport       5517 non-null   object
#  6   StreamingTV       5517 non-null   object
#  7   StreamingMovies   5517 non-null   object
# dtypes: object(8)
# memory usage: 344.9+ KB

# %% [markdown]
# В этом файле мы видим информацию о пользователях услугами интернет. Фаил так же содержитстолбец 'customerID', что позволит объеденить его с двумя предыдущими, однако, здесть меньше строк, что говорит о том, что не все клиенты пользуются услугами internet. При объединении получим пропуски, будем заполнять .

# %% [markdown]
# Проверим на аномалии.

# %%
internet['InternetService'].unique()
# Out:
# array(['DSL', 'Fiber optic'], dtype=object)

# %%
internet['OnlineSecurity'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
internet['OnlineBackup'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
internet['DeviceProtection'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
internet['TechSupport'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
internet['StreamingTV'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
internet['StreamingMovies'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %% [markdown]
# Данные готовы к работе

# %% [markdown]
# #### Четвертый фаил

# %%
try:
    phone = pd.read_csv('/datasets/final_provider/phone.csv')
except:
    phone = pd.read_csv('phone.csv')
phone
# Out:
#       customerID MultipleLines
# 0     5575-GNVDE            No
# 1     3668-QPYBK            No
# 2     9237-HQITU            No
# 3     9305-CDSKC           Yes
# 4     1452-KIOVK           Yes
# ...          ...           ...
# 6356  2569-WGERO            No
# 6357  6840-RESVB           Yes
# 6358  2234-XADUH           Yes
# 6359  8361-LTMKD           Yes
# 6360  3186-AJIEK            No
#
# [6361 rows x 2 columns]

# %%
phone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6361 entries, 0 to 6360
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     6361 non-null   object
#  1   MultipleLines  6361 non-null   object
# dtypes: object(2)
# memory usage: 99.5+ KB

# %% [markdown]
# В этом файле мы видим данные о пользователях телефонными услугами. Так же есть возможность для объединения данных по id.

# %% [markdown]
# Проверим уникальные значения.

# %%
phone['MultipleLines'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %% [markdown]
# Данные готовы к работе

# %% [markdown]
# ### Вывод по первому этапу

# %% [markdown]
# Данные загружаются и читаются. На первом этапе пропуски отсутствуют, однако появяться на этапе слияния данных. Некоторые столбцы нуждаются в обработке, а именно в смене типа данных. Так же не забываем об обработке данных целевого признака, а именно замене дат расторжения договоров на категорию 'Yes'.

# %% [markdown]
# Перед переходом ко второму этапу составим примерный план дальнейших действий.

# %% [markdown]
# <div class="alert alert-success">
# <b>**Комментарий тимлида ✔️:**</b>
#
# Отлично, с данными ознакомился и убедился что как минимум представленные данные содержат какую-то информацию (не пустые и не откровенный мусор). С ними можно начинать работать более серезьно - проводить полноценный исследовательский анализ и выявлять возможные проблемы в данных.
# </div>

# %% [markdown]
# ### Вопросы по  первому этапу

# %% [markdown]
# 1. Что важнее для заказчика: скорость обучения модели, скорость предсказания или качество итоговой метрики?

# %% [markdown]
# <div class="alert alert-success">
# <b>**Комментарий тимлида ✔️:**</b>
#
# Отлично, есть правильные вопросы по исходным данным и проекту в целом!
#
# Для заказчика важнее получить необходимую метрику. Скорость не важна.
# </div>

# %% [markdown]
# ## План второго этапа.

# %% [markdown]
# 1. Изменение типов данных некоторых столбцов в первом датафрейме и обработка данных целевого признака.
# 2. Слияние таблиц.
# 3. Работа с пропусками в новой таблице.
# 4. Поиск и удаление данных, которые могут привести к утечке данных, методом корреляции.
# 5. Разделение датафрейма на тренировочную и тестовую выборку.
# 6. Создание копии общей базы для кодирования в ней категоральных признаков для некоторых моделей.
# 7. Обучение модели дерева решений и поиск лучших гиперпараметров для нее.
# 8. Обучение модели случайного леса и поиск лучших гиперпараметров для нее.
# 9. Обучение линейной модели и поиск лучших гиперпараметров для нее.
# 10. Обучение модели градиентного бустинга и поиск лучших гиперпараметров для нее.
# 11. Объединение полученных данных в таблицу и выбор лучшей модели для ее последующего тестирования.

# %% [markdown]
# <div class="alert alert-success">
# <b>**Комментарий тимлида ✔️:**</b>
#
# А вот и подробный план работ. Указанны все основные этапы исследования! Вижу что понимаешь что предстоит делать, уверен инструментарий  тоже подберешь верно!
#
# Все-таки хотелось изначально видеть полноценный план на все исследование в целом, а не на каждую часть отдельно. Было бы не плохо, если ты сделаешь общий план сразу.
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>**Комментарий тимлида ❌:**</b>
#
# Все почти ок, но данные не грузятся. Надо попроавить и выслать мне на повторную проверку тетрадку.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>**Комментарий тимлида_v2 ✔️:**</b>
#
# Есть план, есть уточняющие вопросы, (вернее их не осталось), есть предварительное исследование данных.
#
# Отлично, работу приниаю, переходи к следующему этапу исследования - разработка модели.
# </div>

# %% [markdown]
# ## Этап второй. Обучение моделей.

# %% [markdown]
# ### Обработка данных

# %% [markdown]
# Начнем с целевого признака. В столбце 'EndDate' мы имеем либо значение 'No', что означает продолжение сотрудничества клиента с компанией, либо дату расторжения договора в формате object. Заменим значение на 0 - клиент продолжает сотрудничество, и 1 - договор расторгнут

# %%
contract.loc[contract['EndDate'] != 'No', 'EndDate'] = 1
contract.loc[contract['EndDate'] == 'No', 'EndDate'] = 0
contract
# Out:
#       customerID   BeginDate EndDate            Type PaperlessBilling  \
# 0     7590-VHVEG  2020-01-01       0  Month-to-month              Yes
# 1     5575-GNVDE  2017-04-01       0        One year               No
# 2     3668-QPYBK  2019-10-01       1  Month-to-month              Yes
# 3     7795-CFOCW  2016-05-01       0        One year               No
# 4     9237-HQITU  2019-09-01       1  Month-to-month              Yes
# ...          ...         ...     ...             ...              ...
# 7038  6840-RESVB  2018-02-01       0        One year              Yes
# 7039  2234-XADUH  2014-02-01       0        One year              Yes
# 7040  4801-JZAZL  2019-03-01       0  Month-to-month              Yes
# 7041  8361-LTMKD  2019-07-01       1  Month-to-month              Yes
# 7042  3186-AJIEK  2014-08-01       0        Two year              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges
# 0              Electronic check           29.85        29.85
# ...

# %% [markdown]
# И проверим полученные данные на уникальность

# %%
contract['EndDate'].unique()
# Out:
# array([0, 1], dtype=object)

# %%
contract['EndDate'] = pd.to_numeric(contract['EndDate'], errors='coerce')

# %% [markdown]
# Теперь заменими типы данных в столбцах 'BeginDate' и 'TotalCharges' на date и float соответственно

# %%
contract['BeginDate'] = pd.to_datetime(contract['BeginDate'])
contract['BeginDate'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7043 entries, 0 to 7042
# Series name: BeginDate
# Non-Null Count  Dtype
# --------------  -----
# 7043 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 55.1 KB

# %%
contract['TotalCharges'] = pd.to_numeric(contract['TotalCharges'], errors='coerce') 
contract['TotalCharges'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7043 entries, 0 to 7042
# Series name: TotalCharges
# Non-Null Count  Dtype
# --------------  -----
# 7032 non-null   float64
# dtypes: float64(1)
# memory usage: 55.1 KB

# %% [markdown]
# С датами получилось все корректно, а вот в колонке 'TotalCharges' мы не смогла перевести 11 значений в числовой формат. Думаю, можно удалить эти строки после слияния таблиц

# %% [markdown]
# ### Слияние таблиц

# %% [markdown]
# Объединим все таблицы в единый датафрейм методом merge. За исходную базу возьмем фаил contract, так как он содержит все данные по всем договорам. Присоединять будем по колонке 'customerID', так как она является общей для всех файлов.

# %%
data = contract.merge(personal, on='customerID', how='left')
data
# Out:
#       customerID  BeginDate  EndDate            Type PaperlessBilling  \
# 0     7590-VHVEG 2020-01-01        0  Month-to-month              Yes
# 1     5575-GNVDE 2017-04-01        0        One year               No
# 2     3668-QPYBK 2019-10-01        1  Month-to-month              Yes
# 3     7795-CFOCW 2016-05-01        0        One year               No
# 4     9237-HQITU 2019-09-01        1  Month-to-month              Yes
# ...          ...        ...      ...             ...              ...
# 7038  6840-RESVB 2018-02-01        0        One year              Yes
# 7039  2234-XADUH 2014-02-01        0        One year              Yes
# 7040  4801-JZAZL 2019-03-01        0  Month-to-month              Yes
# 7041  8361-LTMKD 2019-07-01        1  Month-to-month              Yes
# 7042  3186-AJIEK 2014-08-01        0        Two year              Yes
#
#                   PaymentMethod  MonthlyCharges  TotalCharges  gender  \
# ...

# %%
data = data.merge(internet, on='customerID', how='left')

# %%
data = data.merge(phone, on='customerID', how='left')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   BeginDate         7043 non-null   datetime64[ns]
#  2   EndDate           7043 non-null   int64
#  3   Type              7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7032 non-null   float64
#  8   gender            7043 non-null   object
#  9   SeniorCitizen     7043 non-null   int64
#  10  Partner           7043 non-null   object
#  11  Dependents        7043 non-null   object
#  12  InternetService   5517 non-null   object
#  13  OnlineSecurity    5517 non-null   object
#  14  OnlineBackup      5517 non-null   object
#  15  DeviceProtection  5517 non-null   object
# ...

# %% [markdown]
# Заполним пропуски нулями, так как пропуски в новой таблице означают, что клиент просто не пользуется услугами интернета или телефонии

# %%
data = data.fillna('0')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   BeginDate         7043 non-null   datetime64[ns]
#  2   EndDate           7043 non-null   int64
#  3   Type              7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7043 non-null   object
#  8   gender            7043 non-null   object
#  9   SeniorCitizen     7043 non-null   int64
#  10  Partner           7043 non-null   object
#  11  Dependents        7043 non-null   object
#  12  InternetService   7043 non-null   object
#  13  OnlineSecurity    7043 non-null   object
#  14  OnlineBackup      7043 non-null   object
#  15  DeviceProtection  7043 non-null   object
# ...

# %% [markdown]
# Удалим 11 строк с некорректными данными в колонке 'TotalCharges'

# %%
data.drop(data[data.TotalCharges == '0'].index, inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   BeginDate         7032 non-null   datetime64[ns]
#  2   EndDate           7032 non-null   int64
#  3   Type              7032 non-null   object
#  4   PaperlessBilling  7032 non-null   object
#  5   PaymentMethod     7032 non-null   object
#  6   MonthlyCharges    7032 non-null   float64
#  7   TotalCharges      7032 non-null   object
#  8   gender            7032 non-null   object
#  9   SeniorCitizen     7032 non-null   int64
#  10  Partner           7032 non-null   object
#  11  Dependents        7032 non-null   object
#  12  InternetService   7032 non-null   object
#  13  OnlineSecurity    7032 non-null   object
#  14  OnlineBackup      7032 non-null   object
#  15  DeviceProtection  7032 non-null   object
# ...

# %% [markdown]
# И снова тип столбца 'TotalCharges' стал object. Заменим

# %%
data['TotalCharges'] = pd.to_numeric(data['TotalCharges'], errors='coerce') 
data['TotalCharges'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 7032 entries, 0 to 7042
# Series name: TotalCharges
# Non-Null Count  Dtype
# --------------  -----
# 7032 non-null   float64
# dtypes: float64(1)
# memory usage: 109.9 KB

# %% [markdown]
# Так же можно удалить колонку 'customerID', так как она больше не нужна

# %%
data = data.drop(['customerID'], axis=1)

# %% [markdown]
# ### Проверка корреляций

# %% [markdown]
# Проверим уровень корреляции целевого признака с другими данными с целью избежать его утечки при обучении

# %%
phik_overview = data.phik_matrix()
phik_overview.round(2)
# Out:
# interval columns not set, guessing: ['EndDate', 'MonthlyCharges', 'TotalCharges', 'SeniorCitizen']
#                   BeginDate  EndDate  Type  PaperlessBilling  PaymentMethod  \
# BeginDate              1.00     0.51  0.77              0.08           0.47
# EndDate                0.51     1.00  0.25              0.30           0.45
# Type                   0.77     0.25  1.00              0.11           0.28
# PaperlessBilling       0.08     0.30  0.11              1.00           0.37
# PaymentMethod          0.47     0.45  0.28              0.37           1.00
# MonthlyCharges         0.42     0.36  0.39              0.47           0.40
# TotalCharges           0.82     0.28  0.51              0.21           0.35
# gender                 0.02     0.00  0.00              0.00           0.00
# SeniorCitizen          0.05     0.23  0.09              0.24           0.29
# Partner                0.49     0.23  0.18              0.01           0.24
# ...

# %% [markdown]
# Достаточно высокий уровень корреляции с 'BeginDate' и 'PaymentMethod', однако недостаточный, чтобы негативно влиять на обучение. Думаю, данные можно оставить

# %% [markdown]
# ### Разделелие датафрейма

# %% [markdown]
# Разделим базу данных на обучающую и тестовою

# %%
#data_train, data_test = train_test_split(data, test_size=0.25, random_state=121222)

# %% [markdown]
# ### Кодирование признаков

# %% [markdown]
# Проведем кодирование признаков методом OrdinalEncoder для бустинга и деревьев. Для этого создадим копию датафрейма.

# %%
data_ord_enc = data.copy()

# %%
ord_enc = OrdinalEncoder()
data_ord_enc['Type'] = ord_enc.fit_transform(data_ord_enc[['Type']])
data_ord_enc['PaperlessBilling'] = ord_enc.fit_transform(data_ord_enc[['PaperlessBilling']])
data_ord_enc['PaymentMethod'] = ord_enc.fit_transform(data_ord_enc[['PaymentMethod']])
data_ord_enc['gender'] = ord_enc.fit_transform(data_ord_enc[['gender']])
data_ord_enc['Partner'] = ord_enc.fit_transform(data_ord_enc[['Partner']])
data_ord_enc['Dependents'] = ord_enc.fit_transform(data_ord_enc[['Dependents']])
data_ord_enc['InternetService'] = ord_enc.fit_transform(data_ord_enc[['InternetService']])
data_ord_enc['OnlineSecurity'] = ord_enc.fit_transform(data_ord_enc[['OnlineSecurity']])
data_ord_enc['OnlineBackup'] = ord_enc.fit_transform(data_ord_enc[['OnlineBackup']])
data_ord_enc['DeviceProtection'] = ord_enc.fit_transform(data_ord_enc[['DeviceProtection']])
data_ord_enc['TechSupport'] = ord_enc.fit_transform(data_ord_enc[['TechSupport']])
data_ord_enc['StreamingTV'] = ord_enc.fit_transform(data_ord_enc[['StreamingTV']])
data_ord_enc['StreamingMovies'] = ord_enc.fit_transform(data_ord_enc[['StreamingMovies']])
data_ord_enc['MultipleLines'] = ord_enc.fit_transform(data_ord_enc[['MultipleLines']])

# %%
data_ord_enc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7042
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   BeginDate         7032 non-null   datetime64[ns]
#  1   EndDate           7032 non-null   int64
#  2   Type              7032 non-null   float64
#  3   PaperlessBilling  7032 non-null   float64
#  4   PaymentMethod     7032 non-null   float64
#  5   MonthlyCharges    7032 non-null   float64
#  6   TotalCharges      7032 non-null   float64
#  7   gender            7032 non-null   float64
#  8   SeniorCitizen     7032 non-null   int64
#  9   Partner           7032 non-null   float64
#  10  Dependents        7032 non-null   float64
#  11  InternetService   7032 non-null   float64
#  12  OnlineSecurity    7032 non-null   float64
#  13  OnlineBackup      7032 non-null   float64
#  14  DeviceProtection  7032 non-null   float64
#  15  TechSupport       7032 non-null   float64
# ...

# %%
#data_ord_enc[['Type', 'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges', 
              #'TotalCharges', 'gender', 'Partner', 'Dependents',
             #'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
              #'TechSupport', 'StreamingTV', 'StreamingMovies', 'MultipleLines']].astype(int)

# %%
data_ord_train, data_ord_test = train_test_split(data_ord_enc, test_size=0.25, random_state=121222)

# %% [markdown]
# Для линейных моделей создадим отделный фрейм с прямым кодированием категоральных данных

# %%
#data_ohe = pd.get_dummies(data, drop_first=True)
#data_ohe

# %%
#data_ohe.info()

# %%
#data_ohe_train, data_ohe_test = train_test_split(data_ohe, test_size=0.25, random_state=121222)

# %% [markdown]
# ### Обучение моделей

# %% [markdown]
# Выделим признаки

# %%
target_train = data_ord_train['EndDate']
features_train = data_ord_train.drop('EndDate', axis=1)

# %% [markdown]
# На всякий случай величим выборку отбалансировав целевой признак

# %%
def upsample(features, target, repeat):
    features_zeros = features[target == 0]
    features_ones = features[target == 1]
    target_zeros = target[target == 0]
    target_ones = target[target == 1]

    features_upsampled = pd.concat([features_zeros] + [features_ones] * repeat)
    target_upsampled = pd.concat([target_zeros] + [target_ones] * repeat)
    
    features_upsampled, target_upsampled = shuffle(
        features_upsampled, target_upsampled, random_state=121222)
    
    return features_upsampled, target_upsampled

features_upsampled, target_upsampled = upsample(features_train, target_train, 3)

# %% [markdown]
# Создадим фрейм для объедеинения результатов обучения

# %%
models = pd.DataFrame(columns=['Model', 'ROC_AUC'])
def metrics(model_name, roc_auc, df):
    
    df.loc[model_name,'Model'] = model_name
    df.loc[model_name,'ROC_AUC'] = roc_auc
    
    return df

# %% [markdown]
# #### CatBoostClassifier

# %%
CBC = CatBoostClassifier(random_state=121222)
parameters = {'depth': [2, 3, 4, 5, 6, 7, 8, 9, 10],
                 'learning_rate' : [0.4, 0.5, 0.6, 0.7],
                  'iterations'    : [300, 310, 320, 330, 340, 350, 360]
                 }

# %%
grid = GridSearchCV(estimator=CBC, param_grid = parameters, cv = 4, n_jobs=-1, scoring='roc_auc')
grid.fit(features_train, target_train)
print("best parameters ", grid.best_params_)
print("roc_auc :", grid.best_score_)
metrics('CatBoostClassifier', grid.best_score_, models)
# Out:
# 0:	learn: 0.4921116	total: 51.9ms	remaining: 18.6s
# 1:	learn: 0.4465348	total: 58.2ms	remaining: 10.4s
# 2:	learn: 0.4124968	total: 61ms	remaining: 7.26s
# 3:	learn: 0.3986366	total: 63.3ms	remaining: 5.64s
# 4:	learn: 0.3907975	total: 66.1ms	remaining: 4.69s
# 5:	learn: 0.3851833	total: 68.3ms	remaining: 4.03s
# 6:	learn: 0.3795941	total: 70.5ms	remaining: 3.55s
# 7:	learn: 0.3721534	total: 73.1ms	remaining: 3.21s
# 8:	learn: 0.3703237	total: 75.5ms	remaining: 2.95s
# 9:	learn: 0.3686622	total: 78ms	remaining: 2.73s
# 10:	learn: 0.3621762	total: 80.9ms	remaining: 2.57s
# 11:	learn: 0.3592235	total: 83.7ms	remaining: 2.43s
# 12:	learn: 0.3535739	total: 86.7ms	remaining: 2.31s
# 13:	learn: 0.3518872	total: 89.3ms	remaining: 2.21s
# 14:	learn: 0.3485793	total: 92ms	remaining: 2.12s
# 15:	learn: 0.3460472	total: 94.7ms	remaining: 2.04s
# 16:	learn: 0.3447425	total: 97.5ms	remaining: 1.97s
# 17:	learn: 0.3427181	total: 100ms	remaining: 1.9s
# ...

# %% [markdown]
# #### DecisionTreeClassifier

# %% [markdown]
# Не уверен, что дерево решений корректно воспримет колонку "BeginDate". Удалим

# %%
features_train_new = features_train.drop(['BeginDate'], axis=1)

# %%
params = {'max_leaf_nodes': list(range(2, 100)), 'min_samples_split': [2, 3, 4, 5, 6, 7, 8]}
grid_search_cv = GridSearchCV(DecisionTreeClassifier(random_state=121222), params, verbose=1, cv=4, scoring='roc_auc')
grid_search_cv.fit(features_train_new, target_train)
print("best parameters ", grid_search_cv.best_params_)
print("roc_auc :", grid_search_cv.best_score_)
metrics('DecisionTreeClassifier', grid_search_cv.best_score_, models)
# Out:
# Fitting 4 folds for each of 686 candidates, totalling 2744 fits
# best parameters  {'max_leaf_nodes': 16, 'min_samples_split': 2}
# roc_auc : 0.825041967653845
#                                          Model   ROC_AUC
# CatBoostClassifier          CatBoostClassifier  0.944446
# DecisionTreeClassifier  DecisionTreeClassifier  0.825042

# %% [markdown]
# Проверим на отбалансированной выборке

# %%
features_upsampled_train_new = features_upsampled.drop(['BeginDate'], axis=1)

# %%
params = {'max_leaf_nodes': list(range(2, 100)), 'min_samples_split': [2, 3, 4, 5, 6, 7, 8]}
grid_search_cv = GridSearchCV(DecisionTreeClassifier(random_state=121222), params, verbose=1, cv=4, scoring='roc_auc')
grid_search_cv.fit(features_upsampled_train_new, target_upsampled)
print("best parameters ", grid_search_cv.best_params_)
print("roc_auc :", grid_search_cv.best_score_)
metrics('DecisionTreeClassifier_upsampled', grid_search_cv.best_score_, models)
# Out:
# Fitting 4 folds for each of 686 candidates, totalling 2744 fits
# best parameters  {'max_leaf_nodes': 99, 'min_samples_split': 8}
# roc_auc : 0.843063208655485
#                                                              Model   ROC_AUC
# CatBoostClassifier                              CatBoostClassifier  0.944446
# DecisionTreeClassifier                      DecisionTreeClassifier  0.825042
# DecisionTreeClassifier_upsampled  DecisionTreeClassifier_upsampled  0.843063

# %% [markdown]
# #### LogisticRegression

# %%
grid_log_reg={"C":np.logspace(-10,10, 15), "penalty":["l1", "l2", "none"]}
logreg=LogisticRegression(random_state=121222)
logreg_cv=GridSearchCV(logreg, grid_log_reg, cv=10, scoring='roc_auc')
logreg_cv.fit(features_train_new, target_train)

print("best parameters ", logreg_cv.best_params_)
print("roc_auc :", logreg_cv.best_score_)
metrics('LogisticRegression', logreg_cv.best_score_, models)
# Out:
# C:\Users\Sergey\anaconda31\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Sergey\anaconda31\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Sergey\anaconda31\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# ...

# %% [markdown]
# Так же на отбалансированной выборке

# %%
grid_log_reg={"C":np.logspace(-10,10, 15), "penalty":["l1", "l2", "none"]}
logreg=LogisticRegression(random_state=121222)
logreg_cv=GridSearchCV(logreg, grid_log_reg, cv=10, scoring='roc_auc')
logreg_cv.fit(features_upsampled_train_new, target_upsampled)

print("best parameters ", logreg_cv.best_params_)
print("roc_auc :", logreg_cv.best_score_)
metrics('LogisticRegression_upsampled', logreg_cv.best_score_, models)
# Out:
# C:\Users\Sergey\anaconda31\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Sergey\anaconda31\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Sergey\anaconda31\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# ...

# %% [markdown]
# #### Анализ полученных результатов

# %% [markdown]
# Посмотрим данные общей таблицы и выберем лучшую модель

# %%
models
# Out:
#                                                              Model   ROC_AUC
# CatBoostClassifier                              CatBoostClassifier  0.944446
# DecisionTreeClassifier                      DecisionTreeClassifier  0.825042
# DecisionTreeClassifier_upsampled  DecisionTreeClassifier_upsampled  0.843063
# LogisticRegression                              LogisticRegression  0.832277
# LogisticRegression_upsampled          LogisticRegression_upsampled  0.833695

# %% [markdown]
# Лучшей моделью стала CatBoostClassifier с метрикой ROC-AUC равной 0.944446 на тренировочной выборке.

# %% [markdown]
# #### Проверка на тествой выборке

# %%
target_test = data_ord_test['EndDate']
features_test = data_ord_test.drop('EndDate', axis=1)

# %%
model_final = CatBoostClassifier(random_state=121222, depth = 2, iterations = 360, learning_rate = 0.7)
model_final.fit(features_train, target_train)
test_predict = model_final.predict(features_test)
print("roc_auc на тестовой выборке:", roc_auc_score(target_test, test_predict))
# Out:
# 0:	learn: 0.4921116	total: 3.77ms	remaining: 1.35s
# 1:	learn: 0.4465348	total: 6.92ms	remaining: 1.24s
# 2:	learn: 0.4124968	total: 10.5ms	remaining: 1.25s
# 3:	learn: 0.3986366	total: 13.5ms	remaining: 1.2s
# 4:	learn: 0.3907975	total: 16.4ms	remaining: 1.17s
# 5:	learn: 0.3851833	total: 19.2ms	remaining: 1.13s
# 6:	learn: 0.3795941	total: 22.8ms	remaining: 1.15s
# 7:	learn: 0.3721534	total: 25.6ms	remaining: 1.13s
# 8:	learn: 0.3703237	total: 28.4ms	remaining: 1.11s
# 9:	learn: 0.3686622	total: 31ms	remaining: 1.08s
# 10:	learn: 0.3621762	total: 34.1ms	remaining: 1.08s
# 11:	learn: 0.3592235	total: 37.2ms	remaining: 1.08s
# 12:	learn: 0.3535739	total: 40.1ms	remaining: 1.07s
# 13:	learn: 0.3518872	total: 42.4ms	remaining: 1.05s
# 14:	learn: 0.3485793	total: 44.8ms	remaining: 1.03s
# 15:	learn: 0.3460472	total: 47.5ms	remaining: 1.02s
# 16:	learn: 0.3447425	total: 49.9ms	remaining: 1s
# 17:	learn: 0.3427181	total: 52.6ms	remaining: 1000ms
# ...

# %% [markdown]
# Оценим важность признаков.

# %%
importance = pd.Series(model_final.feature_importances_,
                         data.drop(['EndDate'], axis=1).columns)

fig, ax = plt.subplots(figsize=(16,14))
importance.plot.bar(ax=ax)
ax.set_title("Важность признаков")
ax.set_ylabel('Важность')
fig.tight_layout()
